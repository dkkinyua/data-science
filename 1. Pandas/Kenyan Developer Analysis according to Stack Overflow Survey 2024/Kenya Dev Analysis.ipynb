# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\LENOVO\Documents\Denzel's Prrojects\data-science\1. Pandas\1. Evaluating the results of the StackOverflow 2024 Developer Survey using Pandas\kenya_data.csv")
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0       39795                     I am a developer by profession
# 1       40477  I am not primarily a developer, but I write co...
# 2       28726                     I am a developer by profession
# 3       37974                     I am a developer by profession
# 4        8003                     I am a developer by profession
# 5        6831                     I am a developer by profession
# 6       17174                     I am a developer by profession
# 7       41021                     I am a developer by profession
# 8       12269                     I am a developer by profession
# 9       18742  I am not primarily a developer, but I write co...
#
#                Age                                         Employment  \
# 0  25-34 years old  Employed, full-time;Independent contractor, fr...
# 1  25-34 years old  Employed, full-time;Independent contractor, fr...
# ...

# %%
pd.set_option('display.max_columns', 114)

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0       39795                     I am a developer by profession
# 1       40477  I am not primarily a developer, but I write co...
# 2       28726                     I am a developer by profession
# 3       37974                     I am a developer by profession
# 4        8003                     I am a developer by profession
# 5        6831                     I am a developer by profession
# 6       17174                     I am a developer by profession
# 7       41021                     I am a developer by profession
# 8       12269                     I am a developer by profession
# 9       18742  I am not primarily a developer, but I write co...
#
#                Age                                         Employment  \
# 0  25-34 years old  Employed, full-time;Independent contractor, fr...
# 1  25-34 years old  Employed, full-time;Independent contractor, fr...
# ...

# %% [markdown]
# # Visualizing programming languages used by Kenyan developers.
#
# I would like to get what languages Kenyan developers use in their daily work and visualize them into a bar chart.
# These languages might be many, of course, but I'd like to narrow down to the most commonly used languages globally like Python, Javascript, Typescript, Java, Go, Kotlin among others

# %%
df["LanguageHaveWorkedWith"]
# Out:
# 0      HTML/CSS;Java;JavaScript;Python;Scala;SQL;Type...
# 1                                    JavaScript;Ruby;SQL
# 2      C;Dart;HTML/CSS;Java;JavaScript;Kotlin;PowerSh...
# 3                         HTML/CSS;JavaScript;TypeScript
# 4                                      C#;JavaScript;PHP
#                              ...
# 175                                                  NaN
# 176                                  HTML/CSS;Python;SQL
# 177                HTML/CSS;JavaScript;Python;TypeScript
# 178                                                  NaN
# 179                           HTML/CSS;JavaScript;Python
# Name: LanguageHaveWorkedWith, Length: 180, dtype: object

# %%
df["LanguageHaveWorkedWith"].unique()
# Out:
# array(['HTML/CSS;Java;JavaScript;Python;Scala;SQL;TypeScript',
#        'JavaScript;Ruby;SQL',
#        'C;Dart;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Python;SQL;TypeScript',
#        'HTML/CSS;JavaScript;TypeScript', 'C#;JavaScript;PHP',
#        'Bash/Shell (all shells);C;C++;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#        'Dart;TypeScript', 'Kotlin;Python',
#        'Assembly;C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;PHP;PowerShell;Python;R;SQL;Swift;TypeScript;VBA;Visual Basic (.Net)',
#        'Python;R;SQL',
#        'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python',
#        'Dart;JavaScript;SQL',
#        'C;HTML/CSS;JavaScript;MATLAB;Python;SQL;TypeScript',
#        'Bash/Shell (all shells);C;Go;HTML/CSS;JavaScript;PowerShell;Python;Ruby;SQL;Visual Basic (.Net)',
#        'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;R;Rust;SQL',
#        'C++;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
# ...

# %%
langs_list = ["Python", "Kotlin", "Go", "Ruby", "Rust", "C", "C++", "JavaScript", "TypeScript", "C#", "PHP", "Dart", "Scala", "R", "Lua", "HTML/CSS", "SQL", "Java", "Swift"]
votes = []

for i in langs_list:
    filt = (df["LanguageHaveWorkedWith"].str.contains(i, na=False)).value_counts()
    count = filt.get(True, 0)
    votes.append(count)
votes
# Out:
# [106, 23, 29, 11, 20, 132, 132, 128, 74, 34, 49, 22, 4, 41, 8, 104, 97, 140, 6]

# %%
import matplotlib.pyplot as plt

plt.title("A graph showing different programming languages used by Kenyan developers in 2024")
plt.xlabel("Programming Languages")
plt.xticks(rotation=90) # Rotates the labels on the x-axis by 45deg to avoid overlapping
plt.ylabel("Number of developers")
plt.bar(langs_list, votes)
# Out:
# <BarContainer object of 19 artists>

# %% [markdown]
# # Visualizing the working arrangements used by Kenyan developers who took this survey
#
# Let's visualize the working arrangements used by Kenyan developers who took this survey, that is, if they work fully remote, on site or have a hybrid working environment using a pie chart.

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0       39795                     I am a developer by profession
# 1       40477  I am not primarily a developer, but I write co...
# 2       28726                     I am a developer by profession
# 3       37974                     I am a developer by profession
# 4        8003                     I am a developer by profession
# 5        6831                     I am a developer by profession
# 6       17174                     I am a developer by profession
# 7       41021                     I am a developer by profession
# 8       12269                     I am a developer by profession
# 9       18742  I am not primarily a developer, but I write co...
#
#                Age                                         Employment  \
# 0  25-34 years old  Employed, full-time;Independent contractor, fr...
# 1  25-34 years old  Employed, full-time;Independent contractor, fr...
# ...

# %%
# Let's create a list of the values of the arrangements
work = list(df["RemoteWork"].value_counts())
work
# Out:
# [47, 45, 36]

# %%
arrangements = ["Hybrid", "Remote", "In-person"]

plt.title("A chart showing the working arrangement of some Kenyan developers")
plt.pie(work, labels=arrangements, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2c77a9f2870>,
# ...
#  [Text(0.4457654454054889, 1.005630731273884, 'Hybrid'),
#   Text(-1.060153672374984, -0.2933840332223881, 'Remote'),
#   Text(0.6978326125800102, -0.8503114986990107, 'In-person')],
#  [Text(0.24314478840299392, 0.5485258534221183, '36.7%'),
#   Text(-0.578265639477264, -0.16002765448493894, '35.2%'),
#   Text(0.38063597049818737, -0.46380627201764213, '28.1%')])
